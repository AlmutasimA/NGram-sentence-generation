# %%
import collections
import random

# %%
def create_ngram_models(textPath):
  """
  Creates unigram, bigram, and trigram models and vocabulary from a text file.

  Args:
      textPath (str): The path to the text file used to generate the models and vocabulary.

  Returns:
      tuple: A tuple containing four dictionaries:
          - vocab: A set of all unique words found in the text.
          - unigrams: Counts of individual words.
          - bigrams: Counts of two consecutive words.
          - trigrams: Counts of three consecutive words.
  """

  # Read text from file
  with open(textPath, 'r', encoding='utf-8') as f:
    text = f.read()

  # Preprocess text (remove punctuation)
  for punct in "!,.?':;":
    text = text.replace(punct, "")

  # Split text into words, ensuring no empty words
  words = [word for word in text.split() if word]

  # Create empty dictionaries for ngrams and vocabulary
  vocab = set()
  unigrams = collections.Counter()
  bigrams = collections.Counter()
  trigrams = collections.Counter()

  # Build vocabulary and count unigrams simultaneously
  for word in words:
    vocab.add(word)
    unigrams[word] += 1

  # Count bigrams and trigrams, handling vocabulary limitations
  for i in range(len(words) - 1):
    prev_word, word = words[i], words[i + 1]
    bigrams[(prev_word, word)] += 1

    if i < len(words) - 2:
      next_word = words[i + 2]
      trigram = (prev_word, word, next_word)

      # Check if all words in the trigram are in the vocabulary
      if all(word in vocab for word in trigram):
        trigrams[trigram] += 1

  return vocab, unigrams, bigrams, trigrams

# %%
# Test
textPath = r"F:\VSCProjects\NGram\NGram-sentence-generation\Vocabulary.txt"

vocab, unigrams, bigrams, trigrams = create_ngram_models(textPath)

print(f"Vocabulary: {vocab}")
print(f"Unigrams: {unigrams}")
print(f"Bigrams: {bigrams}")
print(f"Trigrams: {trigrams}")
# Out:
# Vocabulary: {'Everything', 'gang', 'added', 'laws', 'think', 'accepted', 'eerily', 'sky', 'is', 'inmost', 'whenever', 'horribly', 'goal', 'creating', 'barely', 'annexes', 'KIND', 'stand', 'hysterical', 'attained', 'way--but', 'Foundation”', 'figured', 'confirmation', 'still', 'lose', 'foreign', 'Hebraized', 'disgusted', 'unwholesome', 'mercy', 'hard', 'credentials', 'putrescence', 'faltered', 'fantasmagoria', 'ocean', 'ingots', 'spiritual', 'shadow-studies', 'individual', 'immaculate', 'services', 'question', 'discarded', 'Foundation’s', 'woman', 'battered', 'heirs', 'between', 'sound--goat', 'next', 'wave', 'squinting', 'incomplete', 'WORK', 'Contact', 'Horror', 'consequent', 'curiosity', 'whither', 'unaccountably', 'wish', 'authority', 'Unless', 'conclusively', 'system', 'Vanilla', 'caught', 'incantation', 'IMPLIED', 'SABOATH', 'editions', 'squalidly', 'based', 'college', 'popular', 'chased', 'Gutenberg', 'taxes', 'poison', '2001', 'soon', 'hinted', 'check', 'reaching', 'closed', '2', 'history', 'float', 'set', 'became', 'right', 'Dutch', 'bottles', 'dusted', 'group', 'has', 'exclusion', 'gain', 'earth', 'maze', 'march', 'sorrow', 'looked', 'avenue', 'manager', 'showed', 'servants', 'suggestive', 'additions', 'agencies', 'legal', 'efforts', 'certain', 'sickening', 'educational', 'Mormo', 'overheard', 'V', 'Orientals', 'unhallowed', 's/he', 'They', 'embarked', 'cries', 'conspiracy', 'bound', 'preserved', 'attendance', 'whose', 'sticky', 'anything', 'gone', 'accepting', 'In', 'you', 'forty-two', 'attempt', 'survived', 'mysteries', 'alone', 'receiving', 'user', 'comply', 'VA', 'wildness', 'lower', 'argued', 'overtook', 'Lovecraft', 'rambles', 'depends', 'redistribution', 'organ-notes', 'prowlers', 'rookeries', 'end', 'shapes', 'Compliance', 'run', 'movement', 'prowled', 'real', 'prominently', 'did', 'let', 'sailor', 'humor', 'officers', 'jeer', 'those', 'drawn', 'Great', 'reports', 'intellectual', 'observed', 'FOR', 'darkness', 'Thus', 'leprous', 'welter', 'guises', 'become', '1E2', 'texts', 'gently', 'born', 'basement', 'visions', 'what', 'sacred', 'files', 'growing', 'Gutenberg™', 'objects', 'Explanations', 'midnight', 'put', 'number', 'nighted', 'noisome', 'smuggled', 'legally', 'power', 'extravagant', 'bleated', 'belief', 'Register', 'HORROR', 'nearly', 'youths', 'collapsed', 'Gutenberg”)', 'Murrays', '1B', 'income', 'crumpled', 'outside', 'narrow', 'behavior', 'Borough', 'collapse', 'alliance', 'legend', 'perceived', 'Hall', 'whatsoever', 'trees', 'Al', 'allow', 'leers', 'strain', 'wholesale', 'obscene', 'detail', 'SOTHER', 'lengths', 'Some', 'office', 'abyss', 'Place', 'From', 'stations', 'profound', 'past', 'waves', 'That', 'quiet', 'visited--but', 'until', 'fully', 'drowned', 'sending', '($1', 'duty', 'It', 'empty', '15', 'admitted', 'carelessly', 'defect', 'pedestrian', 'Copyright', 'minor', 'dock-hands', 'believe', 'lack', 'traffic', 'accomplished', 'spent', 'raised', 'laboratory', 'occasional', 'assigned', 'mendicant', 'blacker', 'swift', 'computers', 'protecting', '"Dickensian"', 'complete', 'demon', 'steps', 'reasons', 'text', 'Yezidees', 'panted', 'charities', 'creatures', 'dances', 'congregate', 'goals', 'universes', 'quickly--as', 'parts', 'prophets', 'Then', 'DAMAGES', 'WILL', 'undreamable', '“Plain', 'deny', 'clear-eyed', 'stages', 'howler', 'preserve', '•', 'business', 'ones', 'noted', 'distant', 'areaway', 'At', 'reading', 'prison', '1E', 'official', 'strangeness', 'insolently', 'welcome', 'alterations', 'acute', 'card', 'MERCHANTABILITY', 'references', 'luminosity', 'whine', 'commercial', 'none', 'experiment', 'dancehall', 'iron-railed', 'large', 'fee', 'treatises', 'wedding', 'barked', '1F6', 'Sections', 'shrieking', 'continuity', 'response)', 'boarder', 'evil', 'going', 'Project', 'last', 'stenches', 'produced', 'marvels', 'words--"Lilith', 'white', 'His', 'address', 'rustication', 'escape', 'canals', 'hundreds', 'eye', 'so', 'sensation', 'happen', 'likeliest', 'interpreted', 'deeper', 'conception--a', 'w ...
# Unigrams: Counter({'the': 682, 'and': 493, 'of': 451, 'to': 237, 'a': 234, 'in': 203, 'with': 114, 'was': 107, 'had': 98, 'he': 98, 'or': 97, 'Project': 79, 'for': 77, 'that': 75, 'not': 69, 'his': 67, 'by': 66, 'on': 65, 'from': 65, 'at': 59, 'which': 59, 'The': 57, 'this': 57, 'as': 57, 'it': 56, 'you': 56, 'Gutenberg™': 55, 'work': 51, 'is': 45, 'were': 43, 'all': 42, 'are': 40, 'any': 40, 'Malone': 39, 'him': 35, 'but': 35, 'an': 34, 'works': 32, 'be': 31, 'other': 27, 'its': 27, 'Suydam': 27, 'electronic': 27, 'could': 26, 'when': 25, 'their': 25, 'who': 24, 'they': 24, 'Gutenberg': 23, 'no': 23, 'have': 22, 'old': 22, 'been': 22, 'He': 21, 'Red': 20, 'may': 20, 'terms': 20, 'up': 20, 'some': 20, 'more': 20, 'Foundation': 19, 'about': 18, 'than': 18, 'agreement': 18, 'copyright': 18, 'Hook': 17, 'things': 17, 'one': 17, 'If': 16, 'only': 16, 'United': 15, 'States': 15, 'most': 15, 'now': 15, 'there': 15, 'without': 15, 'certain': 15, 'do': 15, 'where': 14, 'out': 14, 'so': 14, 'them': 14, 'can': 14, 'through': 14, 'It': 13, 'houses': 13, 'very': 13, 'Literary': 13, 'Archive': 13, 'You': 12, 'copy': 12, 'thing': 12, 'much': 12, 'into': 12, 'such': 12, 'what': 12, 'these': 12, 'upon': 12, 'must': 12, 'Suydams': 12, 'church': 12, 'full': 12, 'trademark': 12, 'donations': 12, 'horror': 11, 'laws': 11, 'before': 11, 'we': 11, 'case': 11, 'police': 11, 'would': 11, 'did': 11, 'forth': 11, 'use': 10, 'world': 10, 'away': 10, 'License': 10, 'OF': 10, 'turned': 10, 'once': 10, 'strange': 10, 'among': 10, 'set': 10, 'time': 10, 'They': 10, 'men': 10, 'every': 10, 'night': 10, 'over': 10, 'access': 10, 'paragraph': 10, 'under': 9, 'many': 9, 'found': 9, 'after': 9, 'those': 9, 'people': 9, 'read': 9, 'less': 9, 'if': 9, 'blood': 9, 'including': 9, 'your': 9, 'eBook': 8, 'THE': 8, 'place': 8, 'man': 8, 'long': 8, 'life': 8, 'never': 8, 'till': 8, 'paid': 8, 'knew': 8, 'too': 8, 'near': 8, 'dark': 8, 'nothing': 8, 'In': 8, 'come': 8, 'came': 8, 'state': 8, 'seemed': 8, 'how': 8, 'Robert': 8, 'still': 8, 'law': 8, 'new': 8, 'Then': 8, 'doctor': 8, 'fee': 8, 'refund': 8, 'located': 7, 'will': 7, 'using': 7, 'New': 7, 'phosphorescent': 7, 'Chepachet': 7, 'several': 7, 'sight': 7, 'brick': 7, 'As': 7, 'even': 7, 'To': 7, 'days': 7, 'One': 7, 'around': 7, 'organ': 7, 'down': 7, 'way': 7, 'whose': 7, 'Parker': 7, 'though': 7, 'dance-hall': 7, 'our': 7, 'pedestal': 7, 'US': 7, 'distributing': 7, 'copies': 7, 'eBooks': 7, 'agree': 7, 'Section': 7, 'provide': 7, 'anyone': 6, 'led': 6, 'corpse': 6, 'evil': 6, 'second': 6, 'off': 6, 'sudden': 6, 'leave': 6, 'There': 6, 'something': 6, 'prisoners': 6, 'A': 6, 'But': 6, 'saw': 6, 'last': 6, 'years': 6, 'seen': 6, 'faces': 6, 'here': 6, 'below': 6, 'house': 6, 'heard': 6, 'look': 6, 'basement': 6, 'used': 6, 'part': 6, 'Place': 6, 'number': 6, 'support': 6, 'tramp': 6, 'just': 6, 'again': 6, 'door': 6, 'form': 6, 'permission': 6, 'charge': 6, 'YOU': 6, 'OR': 6, 'distribution': 6, 'associated': 6, 'comply': 6, 'tax': 6, 'This': 5, 'almost': 5, 'check': 5, 'York': 5, 'naked': 5, 'corpulent': 5, 'sometimes': 5, 'return': 5, 'section': 5, 'visible': 5, 'then': 5, 'made': 5, 'raid': 5, 'both': 5, 'relatives': 5, 'first': 5, 'told': 5, 'held': 5, 'Brooklyn': 5, 'death': 5, 'person': 5, 'sense': 5, 'secret': 5, 'make': 5, 'often': 5, 'ancient': 5, 'Borough': 5, 'Hall': 5, 'windows': 5, 'outside': 5, 'least': 5, 'terrible': 5, 'small': 5, 'took': 5, 'means': 5, 'little': 5, 'few': 5, 'friend': 5, 'within': 5, 'curious': 5, 'flat': 5, 'freely': 5, 'great': 5, 'whilst': 5, 'thought': 5, 'Greek': 5, 'red': 5, 'cannot': 5, 'same': 5, 'stateroom': 5, 'has': 5, 'following': 5, 'compliance': 5, 'whole': 5, 'carved': 5, 'protected': 5, 'distribute': 5, 'license': 5, 'free': 5, '“Project': 5, '1E1': 5, 'medium': 5, '1F3': 5, 'received': 5, 'online': 4, 'wwwgutenbergorg': 4, 'country': 4, '***': 4, 'PROJECT': 4, 'By': 4, 'bearing': 4, 'well': 4, 'us': 4, 'my': 4, 'singular': 4, 'hill': 4, 'business': 4, 'buildings': ...
# Bigrams: Counter({('of', 'the'): 95, ('in', 'the'): 60, ('Project', 'Gutenberg™'): 55, ('to', 'the'): 41, ('and', 'the'): 40, ('the', 'Project'): 27, ('on', 'the'): 27, ('with', 'the'): 25, ('Project', 'Gutenberg'): 23, ('from', 'the'): 23, ('of', 'a'): 21, ('by', 'the'): 20, ('of', 'this'): 20, ('at', 'the'): 18, ('he', 'had'): 18, ('Gutenberg™', 'electronic'): 18, ('Red', 'Hook'): 17, ('terms', 'of'): 16, ('electronic', 'works'): 16, ('United', 'States'): 15, ('this', 'agreement'): 15, ('for', 'the'): 14, ('the', 'United'): 14, ('the', 'terms'): 13, ('in', 'a'): 13, ('Gutenberg', 'Literary'): 13, ('Literary', 'Archive'): 13, ('had', 'been'): 12, ('Archive', 'Foundation'): 12, ('If', 'you'): 11, ('all', 'the'): 11, ('electronic', 'work'): 11, ('the', 'work'): 11, ('of', 'his'): 10, ('it', 'was'): 10, ('this', 'work'): 10, ('access', 'to'): 10, ('for', 'a'): 9, ('he', 'was'): 9, ('was', 'a'): 9, ('about', 'the'): 9, ('that', 'the'): 9, ('you', 'are'): 8, ('He', 'had'): 8, ('to', 'his'): 8, ('to', 'be'): 8, ('It', 'was'): 8, ('among', 'the'): 8, ('Malone', 'was'): 8, ('to', 'a'): 8, ('in', 'this'): 8, ('and', 'he'): 8, ('set', 'forth'): 8, ('forth', 'in'): 8, ('do', 'not'): 8, ('Gutenberg™', 'License'): 8, ('of', 'Project'): 8, ('with', 'a'): 7, ('that', 'he'): 7, ('but', 'the'): 7, ('is', 'a'): 7, ('the', 'case'): 7, ('Robert', 'Suydam'): 7, ('or', 'any'): 7, ('copies', 'of'): 7, ('agree', 'to'): 7, ('the', 'full'): 7, ('use', 'of'): 6, ('laws', 'of'): 6, ('phosphorescent', 'thing'): 6, ('on', 'a'): 6, ('which', 'he'): 6, ('of', 'any'): 6, ('which', 'had'): 6, ('and', 'had'): 6, ('could', 'not'): 6, ('seemed', 'to'): 6, ('than', 'the'): 6, ('and', 'its'): 6, ('did', 'not'): 6, ('the', 'Suydam'): 6, ('Parker', 'Place'): 6, ('which', 'the'): 6, ('dance-hall', 'church'): 6, ('work', 'or'): 6, ('the', 'world'): 5, ('You', 'may'): 5, ('with', 'this'): 5, ('are', 'not'): 5, ('check', 'the'): 5, ('the', 'laws'): 5, ('this', 'eBook'): 5, ('New', 'York'): 5, ('in', 'its'): 5, ('corpulent', 'old'): 5, ('and', 'it'): 5, ('is', 'not'): 5, ('as', 'the'): 5, ('and', 'Malone'): 5, ('of', 'them'): 5, ('of', 'things'): 5, ('and', 'less'): 5, ('Borough', 'Hall'): 5, ('state', 'of'): 5, ('the', 'police'): 5, ('as', 'a'): 5, ('have', 'been'): 5, ('the', 'old'): 5, ('part', 'of'): 5, ('any', 'other'): 5, ('not', 'protected'): 5, ('protected', 'by'): 5, ('by', 'US'): 5, ('copyright', 'law'): 5, ('the', 'Foundation'): 5, ('distribution', 'of'): 5, ('comply', 'with'): 5, ('you', 'must'): 5, ('works', 'in'): 5, ('a', 'Project'): 5, ('a', 'refund'): 5, ('in', 'paragraph'): 5, ('work', 'is'): 5, ('Gutenberg™', 'works'): 5, ('work', 'in'): 5, ('full', 'Project'): 5, ('Gutenberg™', 'work'): 5, ('the', 'copyright'): 5, ('or', 'other'): 5, ('at', 'Red'): 4, ('the', 'use'): 4, ('and', 'most'): 4, ('at', 'no'): 4, ('under', 'the'): 4, ('are', 'located'): 4, ('naked', 'phosphorescent'): 4, ('corpse', 'of'): 4, ('it', 'is'): 4, ('the', 'hill'): 4, ('into', 'the'): 4, ('a', 'second'): 4, ('into', 'a'): 4, ('old', 'brick'): 4, ('when', 'he'): 4, ('he', 'saw'): 4, ('of', 'certain'): 4, ('the', 'Red'): 4, ('life', 'and'): 4, ('does', 'not'): 4, ('and', 'a'): 4, ('when', 'the'): 4, ('at', 'least'): 4, ('sometimes', 'in'): 4, ('of', 'old'): 4, ('of', 'Robert'): 4, ('one', 'of'): 4, ('had', 'come'): 4, ('most', 'of'): 4, ('was', 'to'): 4, ('and', 'in'): 4, ('basement', 'flat'): 4, ('the', 'place'): 4, ('the', 'other'): 4, ('they', 'had'): 4, ('did', 'he'): 4, ('as', 'it'): 4, ('work', 'and'): 4, ('he', 'did'): 4, ('of', 'night'): 4, ('again', 'and'): 4, ('the', 'same'): 4, ('the', 'men'): 4, ('the', 'whole'): 4, ('carved', 'golden'): 4, ('US', 'copyright'): 4, ('the', 'trademark'): 4, ('you', 'do'): 4, ('in', 'any'): 4, ('the', 'phrase'): 4, ('phrase', '“Project'): 4, ('a', 'copy'): 4, ('“Project', 'Gutenberg”'): 4, ('you', 'can'): 4, ('associated', 'with'): 4, ('Gutenberg™', 'trademark'): 4, ('provide', 'a'): 4, ('•', 'You'): 4, ('to', 'you'): 4, ('The', 'Project'):  ...
# Trigrams: Counter({('Project', 'Gutenberg™', 'electronic'): 18, ('the', 'Project', 'Gutenberg'): 15, ('the', 'United', 'States'): 14, ('the', 'terms', 'of'): 13, ('Project', 'Gutenberg', 'Literary'): 13, ('Gutenberg', 'Literary', 'Archive'): 13, ('Gutenberg™', 'electronic', 'works'): 12, ('the', 'Project', 'Gutenberg™'): 12, ('Literary', 'Archive', 'Foundation'): 12, ('in', 'the', 'United'): 10, ('terms', 'of', 'this'): 10, ('of', 'this', 'agreement'): 10, ('of', 'the', 'Project'): 8, ('set', 'forth', 'in'): 8, ('Project', 'Gutenberg™', 'License'): 8, ('of', 'Project', 'Gutenberg™'): 8, ('to', 'the', 'Project'): 7, ('terms', 'of', 'the'): 6, ('Gutenberg™', 'electronic', 'work'): 6, ('not', 'protected', 'by'): 5, ('a', 'Project', 'Gutenberg™'): 5, ('Project', 'Gutenberg™', 'works'): 5, ('full', 'Project', 'Gutenberg™'): 5, ('Project', 'Gutenberg™', 'work'): 5, ('at', 'Red', 'Hook'): 4, ('the', 'use', 'of'): 4, ('If', 'you', 'are'): 4, ('the', 'laws', 'of'): 4, ('laws', 'of', 'the'): 4, ('you', 'are', 'located'): 4, ('naked', 'phosphorescent', 'thing'): 4, ('the', 'Red', 'Hook'): 4, ('protected', 'by', 'US'): 4, ('by', 'US', 'copyright'): 4, ('US', 'copyright', 'law'): 4, ('part', 'of', 'this'): 4, ('the', 'phrase', '“Project'): 4, ('work', 'or', 'any'): 4, ('the', 'full', 'Project'): 4, ('Project', 'Gutenberg™', 'trademark'): 4, ('The', 'Project', 'Gutenberg'): 3, ('for', 'the', 'use'): 3, ('United', 'States', 'and'): 3, ('or', 'online', 'at'): 3, ('located', 'in', 'the'): 3, ('check', 'the', 'laws'): 3, ('where', 'you', 'are'): 3, ('phosphorescent', 'thing', 'that'): 3, ('corpse', 'of', 'the'): 3, ('of', 'the', 'corpulent'): 3, ('the', 'corpulent', 'old'): 3, ('for', 'a', 'second'): 3, ('had', 'been', 'a'): 3, ('which', 'he', 'had'): 3, ('and', 'he', 'had'): 3, ('of', 'Robert', 'Suydam'): 3, ('most', 'of', 'the'): 3, ('Malone', 'could', 'not'): 3, ('in', 'Parker', 'Place'): 3, ('the', 'dance-hall', 'church'): 3, ('he', 'did', 'not'): 3, ('"O', 'friend', 'and'): 3, ('friend', 'and', 'companion'): 3, ('and', 'companion', 'of'): 3, ('companion', 'of', 'night'): 3, ('of', 'night', 'thou'): 3, ('night', 'thou', 'who'): 3, ('thou', 'who', 'rejoicest'): 3, ('who', 'rejoicest', 'in'): 3, ('rejoicest', 'in', 'the'): 3, ('in', 'the', 'baying'): 3, ('the', 'baying', 'of'): 3, ('baying', 'of', 'dogs'): 3, ('and', 'spilt', 'blood'): 3, ('who', 'wanderest', 'in'): 3, ('wanderest', 'in', 'the'): 3, ('in', 'the', 'midst'): 3, ('the', 'midst', 'of'): 3, ('midst', 'of', 'shades'): 3, ('of', 'shades', 'among'): 3, ('shades', 'among', 'the'): 3, ('among', 'the', 'tombs'): 3, ('who', 'longest', 'for'): 3, ('longest', 'for', 'blood'): 3, ('for', 'blood', 'and'): 3, ('blood', 'and', 'bringest'): 3, ('and', 'bringest', 'terror'): 3, ('bringest', 'terror', 'to'): 3, ('terror', 'to', 'mortals'): 3, ('look', 'favorably', 'on'): 3, ('favorably', 'on', 'our'): 3, ('on', 'our', 'sacrifices"'): 3, ('the', 'Suydam', 'stateroom'): 3, ('or', 'any', 'other'): 3, ('carved', 'golden', 'pedestal'): 3, ('corpulent', 'old', 'man'): 3, ('the', 'trademark', 'license'): 3, ('you', 'do', 'not'): 3, ('complying', 'with', 'the'): 3, ('free', 'distribution', 'of'): 3, ('of', 'electronic', 'works'): 3, ('all', 'the', 'terms'): 3, ('not', 'agree', 'to'): 3, ('this', 'agreement', 'you'): 3, ('copies', 'of', 'Project'): 3, ('electronic', 'works', 'in'): 3, ('person', 'or', 'entity'): 3, ('as', 'set', 'forth'): 3, ('forth', 'in', 'paragraph'): 3, ('you', 'can', 'do'): 3, ('can', 'do', 'with'): 3, ('If', 'an', 'individual'): 3, ('this', 'work', 'or'): 3, ('to', 'the', 'full'): 3, ('phrase', '“Project', 'Gutenberg”'): 3, ('electronic', 'work', 'is'): 3, ('permission', 'of', 'the'): 3, ('of', 'the', 'copyright'): 3, ('of', 'the', 'work'): 3, ('the', 'copyright', 'holder'): 3, ('this', 'electronic', 'work'): 3, ('any', 'Project', 'Gutenberg™'): 3, ('you', 'received', 'the'): 3, ('received', 'the', 'work'): 3, ('The', 'horror', 'at'): 2, ('horror', 'at', 'Red'): 2, ('is', 'for', 'th ...

# %%
def generate_sentences(initial_words, unigrams, bigrams, trigrams, max_length=10):
  """
  Generates three sentences of a specified length using initial words and n-gram models.

  Args:
      initial_words (list): A list of words to start the generated sentences.
      unigrams (Counter): A dictionary containing counts of individual words.
      bigrams (Counter): A dictionary containing counts of two consecutive words.
      trigrams (Counter): A dictionary containing counts of three consecutive words.
      max_length (int, optional): The maximum length of the generated sentences. Defaults to 10.

  Returns:
      list: A list containing three generated sentences (unigram, bigram, trigram).
  """

  sentences = []

   # Generate sentence using unigrams
  sentence = initial_words.copy()
  while len(sentence) < max_length:
    next_word = random.choices(list(unigrams.keys()), weights=list(unigrams.values()))[0]
    sentence.append(next_word)
  sentences.append(" ".join(sentence).capitalize())

  # Generate sentence using bigrams with fallback to unigrams
  sentence = initial_words.copy()
  while len(sentence) < max_length:
    prev_word, curr_word = sentence[-2:]
    next_word_candidates = [w for w, count in bigrams.items() if w[0] == curr_word]
    if next_word_candidates:
      next_word = random.choices(next_word_candidates, weights=[count for _, count in bigrams.items() if _[0] == curr_word])[0][1]
    else:
      # Fallback to unigrams if no valid bigram found
      next_word = random.choices(list(unigrams.keys()), weights=list(unigrams.values()))[0]
    sentence.append(next_word)
  sentences.append(" ".join(sentence).capitalize())

  # Generate sentence using trigrams with fallback to bigrams/unigrams
  sentence = initial_words.copy()
  while len(sentence) < max_length:
    prev_word1, prev_word2, curr_word = sentence[-3:]
    next_word_candidates = [w for w in trigrams.keys() if w[0] == prev_word2 and w[1] == curr_word]
    if next_word_candidates:
      next_word = random.choices(next_word_candidates, weights=[count for _, count in trigrams.items() if _[0] == prev_word2 and _[1] == curr_word])[0][2]
    else:
      # Fallback to bigrams if no valid trigram found
      prev_word, curr_word = sentence[-2:]
      next_word_candidates = [w for w, count in bigrams.items() if w[0] == curr_word]
      if next_word_candidates:
        next_word = random.choices(next_word_candidates, weights=[count for _, count in bigrams.items() if _[0] == curr_word])[0][1]
      else:
        # Final fallback to unigrams if no valid bigram either (or end of sentence)
        next_word = random.choices(list(unigrams.keys()), weights=list(unigrams.values()))[0]
    sentence.append(next_word)
  sentences.append(" ".join(sentence).capitalize())

  return sentences

# %%
# Example usage
textPath = r"F:\VSCProjects\NGram\NGram-sentence-generation\Vocabulary.txt"

vocab, unigrams, bigrams, trigrams = create_ngram_models(textPath)

print(f"Vocabulary: {vocab}")
print(f"Unigrams: {unigrams}")
print(f"Bigrams: {bigrams}")
print(f"Trigrams: {trigrams}")

# Initial words to start the generated sentences
initial_words = ["the", "gun", "is"]

# Generate three sentences (one for each n-gram model)
sentences = generate_sentences(initial_words, unigrams, bigrams, trigrams)

# Print the generated sentences
print("Generated Sentences:")
for sentence in sentences:
  print(sentence)
# Out:
# Vocabulary: {'Everything', 'gang', 'added', 'laws', 'think', 'accepted', 'eerily', 'sky', 'is', 'inmost', 'whenever', 'horribly', 'goal', 'creating', 'barely', 'annexes', 'KIND', 'stand', 'hysterical', 'attained', 'way--but', 'Foundation”', 'figured', 'confirmation', 'still', 'lose', 'foreign', 'Hebraized', 'disgusted', 'unwholesome', 'mercy', 'hard', 'credentials', 'putrescence', 'faltered', 'fantasmagoria', 'ocean', 'ingots', 'spiritual', 'shadow-studies', 'individual', 'immaculate', 'services', 'question', 'discarded', 'Foundation’s', 'woman', 'battered', 'heirs', 'between', 'sound--goat', 'next', 'wave', 'squinting', 'incomplete', 'WORK', 'Contact', 'Horror', 'consequent', 'curiosity', 'whither', 'unaccountably', 'wish', 'authority', 'Unless', 'conclusively', 'system', 'Vanilla', 'caught', 'incantation', 'IMPLIED', 'SABOATH', 'editions', 'squalidly', 'based', 'college', 'popular', 'chased', 'Gutenberg', 'taxes', 'poison', '2001', 'soon', 'hinted', 'check', 'reaching', 'closed', '2', 'history', 'float', 'set', 'became', 'right', 'Dutch', 'bottles', 'dusted', 'group', 'has', 'exclusion', 'gain', 'earth', 'maze', 'march', 'sorrow', 'looked', 'avenue', 'manager', 'showed', 'servants', 'suggestive', 'additions', 'agencies', 'legal', 'efforts', 'certain', 'sickening', 'educational', 'Mormo', 'overheard', 'V', 'Orientals', 'unhallowed', 's/he', 'They', 'embarked', 'cries', 'conspiracy', 'bound', 'preserved', 'attendance', 'whose', 'sticky', 'anything', 'gone', 'accepting', 'In', 'you', 'forty-two', 'attempt', 'survived', 'mysteries', 'alone', 'receiving', 'user', 'comply', 'VA', 'wildness', 'lower', 'argued', 'overtook', 'Lovecraft', 'rambles', 'depends', 'redistribution', 'organ-notes', 'prowlers', 'rookeries', 'end', 'shapes', 'Compliance', 'run', 'movement', 'prowled', 'real', 'prominently', 'did', 'let', 'sailor', 'humor', 'officers', 'jeer', 'those', 'drawn', 'Great', 'reports', 'intellectual', 'observed', 'FOR', 'darkness', 'Thus', 'leprous', 'welter', 'guises', 'become', '1E2', 'texts', 'gently', 'born', 'basement', 'visions', 'what', 'sacred', 'files', 'growing', 'Gutenberg™', 'objects', 'Explanations', 'midnight', 'put', 'number', 'nighted', 'noisome', 'smuggled', 'legally', 'power', 'extravagant', 'bleated', 'belief', 'Register', 'HORROR', 'nearly', 'youths', 'collapsed', 'Gutenberg”)', 'Murrays', '1B', 'income', 'crumpled', 'outside', 'narrow', 'behavior', 'Borough', 'collapse', 'alliance', 'legend', 'perceived', 'Hall', 'whatsoever', 'trees', 'Al', 'allow', 'leers', 'strain', 'wholesale', 'obscene', 'detail', 'SOTHER', 'lengths', 'Some', 'office', 'abyss', 'Place', 'From', 'stations', 'profound', 'past', 'waves', 'That', 'quiet', 'visited--but', 'until', 'fully', 'drowned', 'sending', '($1', 'duty', 'It', 'empty', '15', 'admitted', 'carelessly', 'defect', 'pedestrian', 'Copyright', 'minor', 'dock-hands', 'believe', 'lack', 'traffic', 'accomplished', 'spent', 'raised', 'laboratory', 'occasional', 'assigned', 'mendicant', 'blacker', 'swift', 'computers', 'protecting', '"Dickensian"', 'complete', 'demon', 'steps', 'reasons', 'text', 'Yezidees', 'panted', 'charities', 'creatures', 'dances', 'congregate', 'goals', 'universes', 'quickly--as', 'parts', 'prophets', 'Then', 'DAMAGES', 'WILL', 'undreamable', '“Plain', 'deny', 'clear-eyed', 'stages', 'howler', 'preserve', '•', 'business', 'ones', 'noted', 'distant', 'areaway', 'At', 'reading', 'prison', '1E', 'official', 'strangeness', 'insolently', 'welcome', 'alterations', 'acute', 'card', 'MERCHANTABILITY', 'references', 'luminosity', 'whine', 'commercial', 'none', 'experiment', 'dancehall', 'iron-railed', 'large', 'fee', 'treatises', 'wedding', 'barked', '1F6', 'Sections', 'shrieking', 'continuity', 'response)', 'boarder', 'evil', 'going', 'Project', 'last', 'stenches', 'produced', 'marvels', 'words--"Lilith', 'white', 'His', 'address', 'rustication', 'escape', 'canals', 'hundreds', 'eye', 'so', 'sensation', 'happen', 'likeliest', 'interpreted', 'deeper', 'conception--a', 'w ...
# Unigrams: Counter({'the': 682, 'and': 493, 'of': 451, 'to': 237, 'a': 234, 'in': 203, 'with': 114, 'was': 107, 'had': 98, 'he': 98, 'or': 97, 'Project': 79, 'for': 77, 'that': 75, 'not': 69, 'his': 67, 'by': 66, 'on': 65, 'from': 65, 'at': 59, 'which': 59, 'The': 57, 'this': 57, 'as': 57, 'it': 56, 'you': 56, 'Gutenberg™': 55, 'work': 51, 'is': 45, 'were': 43, 'all': 42, 'are': 40, 'any': 40, 'Malone': 39, 'him': 35, 'but': 35, 'an': 34, 'works': 32, 'be': 31, 'other': 27, 'its': 27, 'Suydam': 27, 'electronic': 27, 'could': 26, 'when': 25, 'their': 25, 'who': 24, 'they': 24, 'Gutenberg': 23, 'no': 23, 'have': 22, 'old': 22, 'been': 22, 'He': 21, 'Red': 20, 'may': 20, 'terms': 20, 'up': 20, 'some': 20, 'more': 20, 'Foundation': 19, 'about': 18, 'than': 18, 'agreement': 18, 'copyright': 18, 'Hook': 17, 'things': 17, 'one': 17, 'If': 16, 'only': 16, 'United': 15, 'States': 15, 'most': 15, 'now': 15, 'there': 15, 'without': 15, 'certain': 15, 'do': 15, 'where': 14, 'out': 14, 'so': 14, 'them': 14, 'can': 14, 'through': 14, 'It': 13, 'houses': 13, 'very': 13, 'Literary': 13, 'Archive': 13, 'You': 12, 'copy': 12, 'thing': 12, 'much': 12, 'into': 12, 'such': 12, 'what': 12, 'these': 12, 'upon': 12, 'must': 12, 'Suydams': 12, 'church': 12, 'full': 12, 'trademark': 12, 'donations': 12, 'horror': 11, 'laws': 11, 'before': 11, 'we': 11, 'case': 11, 'police': 11, 'would': 11, 'did': 11, 'forth': 11, 'use': 10, 'world': 10, 'away': 10, 'License': 10, 'OF': 10, 'turned': 10, 'once': 10, 'strange': 10, 'among': 10, 'set': 10, 'time': 10, 'They': 10, 'men': 10, 'every': 10, 'night': 10, 'over': 10, 'access': 10, 'paragraph': 10, 'under': 9, 'many': 9, 'found': 9, 'after': 9, 'those': 9, 'people': 9, 'read': 9, 'less': 9, 'if': 9, 'blood': 9, 'including': 9, 'your': 9, 'eBook': 8, 'THE': 8, 'place': 8, 'man': 8, 'long': 8, 'life': 8, 'never': 8, 'till': 8, 'paid': 8, 'knew': 8, 'too': 8, 'near': 8, 'dark': 8, 'nothing': 8, 'In': 8, 'come': 8, 'came': 8, 'state': 8, 'seemed': 8, 'how': 8, 'Robert': 8, 'still': 8, 'law': 8, 'new': 8, 'Then': 8, 'doctor': 8, 'fee': 8, 'refund': 8, 'located': 7, 'will': 7, 'using': 7, 'New': 7, 'phosphorescent': 7, 'Chepachet': 7, 'several': 7, 'sight': 7, 'brick': 7, 'As': 7, 'even': 7, 'To': 7, 'days': 7, 'One': 7, 'around': 7, 'organ': 7, 'down': 7, 'way': 7, 'whose': 7, 'Parker': 7, 'though': 7, 'dance-hall': 7, 'our': 7, 'pedestal': 7, 'US': 7, 'distributing': 7, 'copies': 7, 'eBooks': 7, 'agree': 7, 'Section': 7, 'provide': 7, 'anyone': 6, 'led': 6, 'corpse': 6, 'evil': 6, 'second': 6, 'off': 6, 'sudden': 6, 'leave': 6, 'There': 6, 'something': 6, 'prisoners': 6, 'A': 6, 'But': 6, 'saw': 6, 'last': 6, 'years': 6, 'seen': 6, 'faces': 6, 'here': 6, 'below': 6, 'house': 6, 'heard': 6, 'look': 6, 'basement': 6, 'used': 6, 'part': 6, 'Place': 6, 'number': 6, 'support': 6, 'tramp': 6, 'just': 6, 'again': 6, 'door': 6, 'form': 6, 'permission': 6, 'charge': 6, 'YOU': 6, 'OR': 6, 'distribution': 6, 'associated': 6, 'comply': 6, 'tax': 6, 'This': 5, 'almost': 5, 'check': 5, 'York': 5, 'naked': 5, 'corpulent': 5, 'sometimes': 5, 'return': 5, 'section': 5, 'visible': 5, 'then': 5, 'made': 5, 'raid': 5, 'both': 5, 'relatives': 5, 'first': 5, 'told': 5, 'held': 5, 'Brooklyn': 5, 'death': 5, 'person': 5, 'sense': 5, 'secret': 5, 'make': 5, 'often': 5, 'ancient': 5, 'Borough': 5, 'Hall': 5, 'windows': 5, 'outside': 5, 'least': 5, 'terrible': 5, 'small': 5, 'took': 5, 'means': 5, 'little': 5, 'few': 5, 'friend': 5, 'within': 5, 'curious': 5, 'flat': 5, 'freely': 5, 'great': 5, 'whilst': 5, 'thought': 5, 'Greek': 5, 'red': 5, 'cannot': 5, 'same': 5, 'stateroom': 5, 'has': 5, 'following': 5, 'compliance': 5, 'whole': 5, 'carved': 5, 'protected': 5, 'distribute': 5, 'license': 5, 'free': 5, '“Project': 5, '1E1': 5, 'medium': 5, '1F3': 5, 'received': 5, 'online': 4, 'wwwgutenbergorg': 4, 'country': 4, '***': 4, 'PROJECT': 4, 'By': 4, 'bearing': 4, 'well': 4, 'us': 4, 'my': 4, 'singular': 4, 'hill': 4, 'business': 4, 'buildings': ...
# Bigrams: Counter({('of', 'the'): 95, ('in', 'the'): 60, ('Project', 'Gutenberg™'): 55, ('to', 'the'): 41, ('and', 'the'): 40, ('the', 'Project'): 27, ('on', 'the'): 27, ('with', 'the'): 25, ('Project', 'Gutenberg'): 23, ('from', 'the'): 23, ('of', 'a'): 21, ('by', 'the'): 20, ('of', 'this'): 20, ('at', 'the'): 18, ('he', 'had'): 18, ('Gutenberg™', 'electronic'): 18, ('Red', 'Hook'): 17, ('terms', 'of'): 16, ('electronic', 'works'): 16, ('United', 'States'): 15, ('this', 'agreement'): 15, ('for', 'the'): 14, ('the', 'United'): 14, ('the', 'terms'): 13, ('in', 'a'): 13, ('Gutenberg', 'Literary'): 13, ('Literary', 'Archive'): 13, ('had', 'been'): 12, ('Archive', 'Foundation'): 12, ('If', 'you'): 11, ('all', 'the'): 11, ('electronic', 'work'): 11, ('the', 'work'): 11, ('of', 'his'): 10, ('it', 'was'): 10, ('this', 'work'): 10, ('access', 'to'): 10, ('for', 'a'): 9, ('he', 'was'): 9, ('was', 'a'): 9, ('about', 'the'): 9, ('that', 'the'): 9, ('you', 'are'): 8, ('He', 'had'): 8, ('to', 'his'): 8, ('to', 'be'): 8, ('It', 'was'): 8, ('among', 'the'): 8, ('Malone', 'was'): 8, ('to', 'a'): 8, ('in', 'this'): 8, ('and', 'he'): 8, ('set', 'forth'): 8, ('forth', 'in'): 8, ('do', 'not'): 8, ('Gutenberg™', 'License'): 8, ('of', 'Project'): 8, ('with', 'a'): 7, ('that', 'he'): 7, ('but', 'the'): 7, ('is', 'a'): 7, ('the', 'case'): 7, ('Robert', 'Suydam'): 7, ('or', 'any'): 7, ('copies', 'of'): 7, ('agree', 'to'): 7, ('the', 'full'): 7, ('use', 'of'): 6, ('laws', 'of'): 6, ('phosphorescent', 'thing'): 6, ('on', 'a'): 6, ('which', 'he'): 6, ('of', 'any'): 6, ('which', 'had'): 6, ('and', 'had'): 6, ('could', 'not'): 6, ('seemed', 'to'): 6, ('than', 'the'): 6, ('and', 'its'): 6, ('did', 'not'): 6, ('the', 'Suydam'): 6, ('Parker', 'Place'): 6, ('which', 'the'): 6, ('dance-hall', 'church'): 6, ('work', 'or'): 6, ('the', 'world'): 5, ('You', 'may'): 5, ('with', 'this'): 5, ('are', 'not'): 5, ('check', 'the'): 5, ('the', 'laws'): 5, ('this', 'eBook'): 5, ('New', 'York'): 5, ('in', 'its'): 5, ('corpulent', 'old'): 5, ('and', 'it'): 5, ('is', 'not'): 5, ('as', 'the'): 5, ('and', 'Malone'): 5, ('of', 'them'): 5, ('of', 'things'): 5, ('and', 'less'): 5, ('Borough', 'Hall'): 5, ('state', 'of'): 5, ('the', 'police'): 5, ('as', 'a'): 5, ('have', 'been'): 5, ('the', 'old'): 5, ('part', 'of'): 5, ('any', 'other'): 5, ('not', 'protected'): 5, ('protected', 'by'): 5, ('by', 'US'): 5, ('copyright', 'law'): 5, ('the', 'Foundation'): 5, ('distribution', 'of'): 5, ('comply', 'with'): 5, ('you', 'must'): 5, ('works', 'in'): 5, ('a', 'Project'): 5, ('a', 'refund'): 5, ('in', 'paragraph'): 5, ('work', 'is'): 5, ('Gutenberg™', 'works'): 5, ('work', 'in'): 5, ('full', 'Project'): 5, ('Gutenberg™', 'work'): 5, ('the', 'copyright'): 5, ('or', 'other'): 5, ('at', 'Red'): 4, ('the', 'use'): 4, ('and', 'most'): 4, ('at', 'no'): 4, ('under', 'the'): 4, ('are', 'located'): 4, ('naked', 'phosphorescent'): 4, ('corpse', 'of'): 4, ('it', 'is'): 4, ('the', 'hill'): 4, ('into', 'the'): 4, ('a', 'second'): 4, ('into', 'a'): 4, ('old', 'brick'): 4, ('when', 'he'): 4, ('he', 'saw'): 4, ('of', 'certain'): 4, ('the', 'Red'): 4, ('life', 'and'): 4, ('does', 'not'): 4, ('and', 'a'): 4, ('when', 'the'): 4, ('at', 'least'): 4, ('sometimes', 'in'): 4, ('of', 'old'): 4, ('of', 'Robert'): 4, ('one', 'of'): 4, ('had', 'come'): 4, ('most', 'of'): 4, ('was', 'to'): 4, ('and', 'in'): 4, ('basement', 'flat'): 4, ('the', 'place'): 4, ('the', 'other'): 4, ('they', 'had'): 4, ('did', 'he'): 4, ('as', 'it'): 4, ('work', 'and'): 4, ('he', 'did'): 4, ('of', 'night'): 4, ('again', 'and'): 4, ('the', 'same'): 4, ('the', 'men'): 4, ('the', 'whole'): 4, ('carved', 'golden'): 4, ('US', 'copyright'): 4, ('the', 'trademark'): 4, ('you', 'do'): 4, ('in', 'any'): 4, ('the', 'phrase'): 4, ('phrase', '“Project'): 4, ('a', 'copy'): 4, ('“Project', 'Gutenberg”'): 4, ('you', 'can'): 4, ('associated', 'with'): 4, ('Gutenberg™', 'trademark'): 4, ('provide', 'a'): 4, ('•', 'You'): 4, ('to', 'you'): 4, ('The', 'Project'):  ...
# Trigrams: Counter({('Project', 'Gutenberg™', 'electronic'): 18, ('the', 'Project', 'Gutenberg'): 15, ('the', 'United', 'States'): 14, ('the', 'terms', 'of'): 13, ('Project', 'Gutenberg', 'Literary'): 13, ('Gutenberg', 'Literary', 'Archive'): 13, ('Gutenberg™', 'electronic', 'works'): 12, ('the', 'Project', 'Gutenberg™'): 12, ('Literary', 'Archive', 'Foundation'): 12, ('in', 'the', 'United'): 10, ('terms', 'of', 'this'): 10, ('of', 'this', 'agreement'): 10, ('of', 'the', 'Project'): 8, ('set', 'forth', 'in'): 8, ('Project', 'Gutenberg™', 'License'): 8, ('of', 'Project', 'Gutenberg™'): 8, ('to', 'the', 'Project'): 7, ('terms', 'of', 'the'): 6, ('Gutenberg™', 'electronic', 'work'): 6, ('not', 'protected', 'by'): 5, ('a', 'Project', 'Gutenberg™'): 5, ('Project', 'Gutenberg™', 'works'): 5, ('full', 'Project', 'Gutenberg™'): 5, ('Project', 'Gutenberg™', 'work'): 5, ('at', 'Red', 'Hook'): 4, ('the', 'use', 'of'): 4, ('If', 'you', 'are'): 4, ('the', 'laws', 'of'): 4, ('laws', 'of', 'the'): 4, ('you', 'are', 'located'): 4, ('naked', 'phosphorescent', 'thing'): 4, ('the', 'Red', 'Hook'): 4, ('protected', 'by', 'US'): 4, ('by', 'US', 'copyright'): 4, ('US', 'copyright', 'law'): 4, ('part', 'of', 'this'): 4, ('the', 'phrase', '“Project'): 4, ('work', 'or', 'any'): 4, ('the', 'full', 'Project'): 4, ('Project', 'Gutenberg™', 'trademark'): 4, ('The', 'Project', 'Gutenberg'): 3, ('for', 'the', 'use'): 3, ('United', 'States', 'and'): 3, ('or', 'online', 'at'): 3, ('located', 'in', 'the'): 3, ('check', 'the', 'laws'): 3, ('where', 'you', 'are'): 3, ('phosphorescent', 'thing', 'that'): 3, ('corpse', 'of', 'the'): 3, ('of', 'the', 'corpulent'): 3, ('the', 'corpulent', 'old'): 3, ('for', 'a', 'second'): 3, ('had', 'been', 'a'): 3, ('which', 'he', 'had'): 3, ('and', 'he', 'had'): 3, ('of', 'Robert', 'Suydam'): 3, ('most', 'of', 'the'): 3, ('Malone', 'could', 'not'): 3, ('in', 'Parker', 'Place'): 3, ('the', 'dance-hall', 'church'): 3, ('he', 'did', 'not'): 3, ('"O', 'friend', 'and'): 3, ('friend', 'and', 'companion'): 3, ('and', 'companion', 'of'): 3, ('companion', 'of', 'night'): 3, ('of', 'night', 'thou'): 3, ('night', 'thou', 'who'): 3, ('thou', 'who', 'rejoicest'): 3, ('who', 'rejoicest', 'in'): 3, ('rejoicest', 'in', 'the'): 3, ('in', 'the', 'baying'): 3, ('the', 'baying', 'of'): 3, ('baying', 'of', 'dogs'): 3, ('and', 'spilt', 'blood'): 3, ('who', 'wanderest', 'in'): 3, ('wanderest', 'in', 'the'): 3, ('in', 'the', 'midst'): 3, ('the', 'midst', 'of'): 3, ('midst', 'of', 'shades'): 3, ('of', 'shades', 'among'): 3, ('shades', 'among', 'the'): 3, ('among', 'the', 'tombs'): 3, ('who', 'longest', 'for'): 3, ('longest', 'for', 'blood'): 3, ('for', 'blood', 'and'): 3, ('blood', 'and', 'bringest'): 3, ('and', 'bringest', 'terror'): 3, ('bringest', 'terror', 'to'): 3, ('terror', 'to', 'mortals'): 3, ('look', 'favorably', 'on'): 3, ('favorably', 'on', 'our'): 3, ('on', 'our', 'sacrifices"'): 3, ('the', 'Suydam', 'stateroom'): 3, ('or', 'any', 'other'): 3, ('carved', 'golden', 'pedestal'): 3, ('corpulent', 'old', 'man'): 3, ('the', 'trademark', 'license'): 3, ('you', 'do', 'not'): 3, ('complying', 'with', 'the'): 3, ('free', 'distribution', 'of'): 3, ('of', 'electronic', 'works'): 3, ('all', 'the', 'terms'): 3, ('not', 'agree', 'to'): 3, ('this', 'agreement', 'you'): 3, ('copies', 'of', 'Project'): 3, ('electronic', 'works', 'in'): 3, ('person', 'or', 'entity'): 3, ('as', 'set', 'forth'): 3, ('forth', 'in', 'paragraph'): 3, ('you', 'can', 'do'): 3, ('can', 'do', 'with'): 3, ('If', 'an', 'individual'): 3, ('this', 'work', 'or'): 3, ('to', 'the', 'full'): 3, ('phrase', '“Project', 'Gutenberg”'): 3, ('electronic', 'work', 'is'): 3, ('permission', 'of', 'the'): 3, ('of', 'the', 'copyright'): 3, ('of', 'the', 'work'): 3, ('the', 'copyright', 'holder'): 3, ('this', 'electronic', 'work'): 3, ('any', 'Project', 'Gutenberg™'): 3, ('you', 'received', 'the'): 3, ('received', 'the', 'work'): 3, ('The', 'horror', 'at'): 2, ('horror', 'at', 'Red'): 2, ('is', 'for', 'th ...
# Generated Sentences:
# The gun is with failed assorted may use cries was
# The gun is subject to break it one need not
# The gun is a registered trademark and may not be
